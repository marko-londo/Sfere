# %%
import spacy
import pandas as pd
import re
import stanza
from tqdm import tqdm
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import defaultdict
from collections import Counter
from textblob import TextBlob

tqdm.pandas()

# %%
# Functions

def open_book(filename):
    with open("../../Resources/Cleaned/"+filename+".txt", 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def add_book_to_df(book, book_title):
    # Split the book text into paragraphs
    paragraphs = book.split('\n')
    
    # Clean each paragraph by removing extra whitespace and trimming
    paragraphs = [re.sub(r'\s+', ' ', para.strip()) for para in paragraphs if para.strip()]

    # Create a DataFrame with two columns: book title and the paragraph text
    df = pd.DataFrame({'Title': [book_title] * len(paragraphs), 'Text': paragraphs})
    return df

def correct_entity_type(entity_text, correction_dict):
    # Normalize the entity text (lowercase, remove extra spaces, handle special chars)
    entity_text_normalized = re.sub(r'\s+', ' ', entity_text).lower().strip(" '\"")

    for category, names in correction_dict.items():
        # Normalize and prepare the names in the dictionary
        normalized_names = [re.sub(r'\s+', ' ', name).lower().strip(" '\"") for name in names]
        
        if entity_text_normalized in normalized_names:
            return category
    return None

def find_entities_in_paragraph(paragraph, entities):
    entities_in_paragraph = set()
    for ent_text, ent_type in entities:
        if ent_text in paragraph:
            entities_in_paragraph.add((ent_text, ent_type))
    return list(entities_in_paragraph)

def dialogue_to_df(text):
    pattern = r'"([^"]*)"'
    dialogues = re.findall(pattern, text)
    df_dialogues = pd.DataFrame(dialogues, columns=['Dialogue'])
    return df_dialogues

def key_phrase_extractor(text, n=1):
    additional_stopwords = {'said', "'s", "n't", "'m", "'re", "'ve", "'ll", "'d"}
    custom_stopwords = set(stopwords.words('english')).union(additional_stopwords)

    # Tokenize the text into words, remove punctuation with regex
    words = word_tokenize(re.sub(r'[^\w\s]', '', text))

    # Remove stop words and convert to lowercase
    words_without_stopwords = [word.lower() for word in words if word.lower() not in custom_stopwords]

    # Generate n-grams
    n_grams = ngrams(words_without_stopwords, n)
    n_grams = [' '.join(grams) for grams in n_grams]

    # Count the frequency of each n-gram
    frequency = Counter(n_grams)

    # Get the top N key phrases
    N = 100
    key_phrases = frequency.most_common(N)

    # Create a DataFrame from the top key phrases
    df = pd.DataFrame(key_phrases, columns=['phrase', 'count'])

    return df

def is_character(entity):
    character_types = {'PERSON'}
    return entity[1] in character_types

def is_location(entity):
    location_types = {'LOC'}
    return entity[1] in location_types


def df_to_csv(df, filename):
    df.to_csv("../../Resources/Cleaned/"+filename+".csv", index=False)

# %%
book = open_book("dying_earth2_cleaned")

# %%
de2_df_para = add_book_to_df(book, "The Eyes of the Overworld")

# %%
de2_df_para
# Out:
#                          Title  \
# 0    The Eyes of the Overworld
# 1    The Eyes of the Overworld
# 2    The Eyes of the Overworld
# 3    The Eyes of the Overworld
# 4    The Eyes of the Overworld
# ..                         ...
# 682  The Eyes of the Overworld
# 683  The Eyes of the Overworld
# 684  The Eyes of the Overworld
# 685  The Eyes of the Overworld
# 686  The Eyes of the Overworld
#
#                                                   Text
# 0    The Overworld! ON THE HEIGHTS above the river ...
# 1    Behind the manse and across the valley, low hi...
# 2    Cugel was a man of many capabilities, with a d...
# 3    These, stamped with appropriate seals and rune...
# 4    Unfortunately for Cugel, not twenty paces from...
# ..                                                 ...
# 682  Cugel uttered a harsh laugh. "I seem to have p...
# 683  I shall not do so a second time. Iucounu, your...
# 684  "The destination is as before: to the shore of...
# 685  For a day and a night the demon dew, grumbling...
# 686  There was silence. To right and left spread th...
#
# [687 rows x 2 columns]

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize,ner')
doc = nlp(book)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dontb\01\001\Repos\Dying-Earth\Notebooks\03-Feature-Extraction\dying_earth_2_feature_extraction.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dontb/01/001/Repos/Dying-Earth/Notebooks/03-Feature-Extraction/dying_earth_2_feature_extraction.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> nlp = stanza.Pipeline(lang='en', processors='tokenize,ner')
#       <a href='vscode-notebook-cell:/c%3A/Users/dontb/01/001/Repos/Dying-Earth/Notebooks/03-Feature-Extraction/dying_earth_2_feature_extraction.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> doc = nlp(book)
#
# NameError: name 'stanza' is not defined

# %%
entities = []
for ent in doc.entities:
    entities.append((ent.text, ent.type))
entities
# Out:
# [('Overworld', 'PERSON'),
#  ('Xzan', 'LOC'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('three', 'CARDINAL'),
#  ('Xzan', 'GPE'),
#  ('the Old Forest', 'LOC'),
#  ('Almery', 'GPE'),
#  ('three', 'CARDINAL'),
#  ('Scaum', 'FAC'),
#  ('Azenomei', 'GPE'),
#  ('Azenomei Fair Cugel', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('the Azenomei Fair', 'EVENT'),
#  ('Cugel', 'PERSON'),
#  ('twenty', 'CARDINAL'),
#  ('Fianosther', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('the third day', 'DATE'),
#  ('Cugel', 'ORG'),
#  ('only four', 'CARDINAL'),
#  ('Fianosther', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('the night', 'TIME'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Dibarcas Maior', 'PERSON'),
#  ('Great Phandaal', 'LOC'),
#  ('at least three hours', 'TIME'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('Three hours', 'TIME'),
#  ('Iucounu', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Kar-kod', 'FAC'),
#  ('twelve thousand', 'CARDINAL'),
#  ('Iucounu', 'PERSON'),
#  ('Grand Motholam', 'LOC'),
#  ('ten or twelve', 'CARDINAL'),
#  ('the Age of Glow', 'WORK_OF_ART'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Xzan', 'FAC'),
#  ('Cugel', 'PERSON'),
#  ('Xzan', 'PERSON'),
#  ('dozen', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Fianosther', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Iucounu', 'GPE'),
#  ('six', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('nine', 'CARDINAL'),
#  ('hundreds', 'CARDINAL'),
#  ('Phandaal', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('three', 'CARDINAL'),
#  ('Azenomei', 'GPE'),
#  ('Fianosther', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Fianosther', 'ORG'),
#  ('Iucounu', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('two feet', 'QUANTITY'),
#  ('second', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('a few feet', 'QUANTITY'),
#  ('Cugel', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the years', 'DATE'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('One', 'CARDINAL'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('White Als-ter', 'GPE'),
#  ('Iucounu', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Thief-taker', 'PERSON'),
#  ('Thief-taker', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Fianos', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the Charm of Forlorn Encystment', 'FAC'),
#  ('Some forty-five  miles', 'QUANTITY'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Iucounu', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Iucounu', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Unda-Hrada', 'FAC'),
#  ("16-04 Green in Thrump's Almanac", 'WORK_OF_ART'),
#  ('La-Er', 'GPE'),
#  ('La-Er', 'GPE'),
#  ('Cutz', 'PERSON'),
#  ('One', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('La-Er', 'GPE'),
#  ('Cutz', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('day', 'DATE'),
#  ('Iucounu', 'PERSON'),
#  ('First', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Achernar', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Azenomei', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'GPE'),
#  ('Xzan', 'LOC'),
#  ('Xzan', 'GPE'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('tomorrow', 'DATE'),
#  ('Iucounu', 'PERSON'),
#  ('the Forlorn Encystment', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Iucounu', 'PERSON'),
#  ("Thas-drubal's", 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the Maurenron Mountains', 'LOC'),
#  ('the Land of the Falling Wall', 'FAC'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('fifteen feet', 'QUANTITY'),
#  ('Cugel', 'PERSON'),
#  ('the Laughing Magician', 'PERSON'),
#  ('A few hundred yards', 'QUANTITY'),
#  ('Cugel', 'PERSON'),
#  ('three', 'CARDINAL'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('the Laughing Magician', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('One', 'CARDINAL'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('The following day', 'DATE'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'PRODUCT'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('about a mile', 'QUANTITY'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('-Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Overworld', 'ORG'),
#  ('Radkuth V', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Overworld', 'NORP'),
#  ('Overworld', 'NORP'),
#  ('Cugel', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Thirty-one years', 'DATE'),
#  ('Bubach Angh', 'PERSON'),
#  ('Thirty-one years', 'DATE'),
#  ('Cugel', 'PERSON'),
#  ('Firs', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Grodz', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Underherd', 'PRODUCT'),
#  ('Earth', 'LOC'),
#  ('Simbilis', 'PERSON'),
#  ('Sixteenth', 'ORDINAL'),
#  ('Four hundred and twelve', 'CARDINAL'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Underherd', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('four hundred and fourteen', 'CARDINAL'),
#  ('four hundred and twelve', 'CARDINAL'),
#  ('Two', 'CARDINAL'),
#  ('second', 'ORDINAL'),
#  ('Grodz', 'GPE'),
#  ('Smolod', 'GPE'),
#  ('Radkuth', 'PERSON'),
#  ('Radkuth', 'PERSON'),
#  ('Radkuth', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Grodz', 'GPE'),
#  ('1', 'CARDINAL'),
#  ('thirty or forty or fifty years', 'DATE'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Radkuth V omin', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Radkuth V', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Radkuth', 'PERSON'),
#  ('Radkuth', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Maulfag', 'PERSON'),
#  ('Glus', 'PERSON'),
#  ('Two', 'CARDINAL'),
#  ('Radkuth V', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'ORG'),
#  ('Grodz', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Radkuth V omin', 'FAC'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('thirty-one years', 'DATE'),
#  ('Smolod', 'NORP'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('The Chief Elder', 'PERSON'),
#  ('Eddith Bran Maur', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('The Chief Eider', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('one foot', 'QUANTITY'),
#  ('minutes', 'TIME'),
#  ('Grodz', 'PERSON'),
#  ('One', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('I am Bu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('thirty-one years', 'DATE'),
#  ('Smolod', 'ORG'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('thirty-one years', 'DATE'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Ten or twelve years', 'DATE'),
#  ('Bubach Angh', 'PERSON'),
#  ('half', 'CARDINAL'),
#  ('Bubach Angh', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Smolod', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Grodz', 'GPE'),
#  ('Radkuth', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Radkuth V', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Grodz', 'GPE'),
#  ('a hundred years', 'DATE'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ("Radkuth V omin's estate", 'FAC'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angfa', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Radkuth V', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Two', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('Smolod', 'NORP'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smofod', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Chief Elder', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'NORP'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Smolod', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('three', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('seven', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('one foot', 'QUANTITY'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('seven', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ("Radkuth V omin's palace", 'FAC'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('tonight', 'TIME'),
#  ('Iucounu', 'GPE'),
#  ('Firx', 'PERSON'),
#  ('Almery', 'ORG'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('seven', 'CARDINAL'),
#  ('Radkuth V omin', 'FAC'),
#  ('Bubach Angh', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('Smolod', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Radkuth V', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ("Bubach Angh's", 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ("Bubach Angh's", 'PERSON'),
#  ("Radkuth V omin's palace", 'FAC'),
#  ('one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('the Valley of the Xzan', 'LOC'),
#  ('Cugel', 'PERSON'),
#  ('the morning', 'TIME'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'LOC'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'NORP'),
#  ('Grodz', 'PERSON'),
#  ('Smolod', 'ORG'),
#  ('The Chief Elder', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Chief Elder', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('a few years', 'DATE'),
#  ('Grodz', 'ORG'),
#  ('Grodz', 'PERSON'),
#  ('a few years', 'DATE'),
#  ('Cugel', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('Bubach Angh', 'PERSON'),
#  ('Udela Narshag', 'PERSON'),
#  ('Zokoxa', 'PERSON'),
#  ('the Rose-Petals', 'FAC'),
#  ('Ilviu Lasmal', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('six swan-feet', 'QUANTITY'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'NORP'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('The Chief Elder', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Udela Narshag', 'PERSON'),
#  ('Zokoxa', 'GPE'),
#  ('Ilviu Lasmal', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Grodz', 'GPE'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Smolod', 'GPE'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Grodz', 'ORG'),
#  ('fifty yards', 'QUANTITY'),
#  ('Bubach Angh', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Smolod', 'GPE'),
#  ('Cugel', 'PRODUCT'),
#  ('six', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Bu-bach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('two miles', 'QUANTITY'),
#  ('one', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'GPE'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('the House of Domber', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Bubach Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bubach', 'PERSON'),
#  ('Angh', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ("Bubach Angh's", 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('Smolod', 'PERSON'),
#  ('Grodz', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Smolod', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Almery', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Cugel', 'GPE'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('half', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('three', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('twenty', 'CARDINAL'),
#  ('Cugel', 'PRODUCT'),
#  ('Cugel', 'PERSON'),
#  ('Earth', 'LOC'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('five minutes', 'TIME'),
#  ('three', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('third', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ("The ghost-king's", 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Farewell', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cil', 'GPE'),
#  ('six', 'CARDINAL'),
#  ('Benbadge Stull', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Bendage Stull', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Benbadge Stull', 'ORG'),
#  ('Falgunto', 'GPE'),
#  ('Mell', 'PRODUCT'),
#  ('Cugel', 'PERSON'),
#  ('Benbadge Stull', 'LOC'),
#  ('Cugel', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('the House of Domber', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('thirty', 'CARDINAL'),
#  ('Cuge', 'PERSON'),
#  ('the House of Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('four', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Al-mery', 'PERSON'),
#  ('Benbadge Stull', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PRODUCT'),
#  ('Cugel', 'PERSON'),
#  ('the morning', 'TIME'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Benbadge', 'GPE'),
#  ('Cil', 'GPE'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('four', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the Azenomei Fair', 'EVENT'),
#  ('Cugel', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('third', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('first', 'ORDINAL'),
#  ('four', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('House', 'ORG'),
#  ('Slaye', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('the House of Domber', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Slaye', 'PERSON'),
#  ('Slayes', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the day', 'DATE'),
#  ('a few minutes', 'TIME'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Great Sandy Beach', 'LOC'),
#  ('Cugel', 'PERSON'),
#  ('tonight', 'TIME'),
#  ('One', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PRODUCT'),
#  ('four', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('a single day', 'DATE'),
#  ('Cugel', 'PERSON'),
#  ('Two', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('One', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the House of Slaye', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('two hundred', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('the space of a day', 'DATE'),
#  ('Firx', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('First', 'ORDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ('the House of Domber', 'ORG'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Benbadge Stull', 'FAC'),
#  ('one', 'CARDINAL'),
#  ('a mile', 'QUANTITY'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('five', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Jight', 'WORK_OF_ART'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('the House of Domber', 'GPE'),
#  ('Cil', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('A minute', 'TIME'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('three', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('night', 'TIME'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Donning', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Sarman', 'PERSON'),
#  ('Bilbab', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cil', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('forty', 'CARDINAL'),
#  ('six', 'CARDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Denve Coreme', 'ORG'),
#  ('the House of Slaye', 'ORG'),
#  ('two hundred', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Yodo', 'ORG'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cil', 'PRODUCT'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Tonight', 'TIME'),
#  ('tonight', 'TIME'),
#  ('tomorrow', 'DATE'),
#  ('tomorrow', 'DATE'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('third', 'ORDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Major-Domo', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Yodo', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cil', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Firx', 'PERSON'),
#  ("Cugel's", 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ("Derwe Coreme's", 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Earth', 'LOC'),
#  ('Iucounu the Laughing Magician', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('The Fourteenth Garth Haxt of Slaye', 'WORK_OF_ART'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('The Eighth Rubel Zaff', 'WORK_OF_ART'),
#  ('Cape Horizon', 'LOC'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('tomorrow', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ("Derwe Dor-erne's", 'PERSON'),
#  ('six', 'CARDINAL'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'ORG'),
#  ('Cugd', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('One', 'CARDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Slaye', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Vanille', 'PERSON'),
#  ('Vanille', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Vanille', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('second', 'ORDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ('Vanille', 'PERSON'),
#  ('Vanille', 'PERSON'),
#  ('Cugel', 'PERSON'),
#  ('Vanille', 'GPE'),
#  ('first', 'ORDINAL'),
#  ('Derwe Coreme', 'PERSON'),
#  ...]

# %%
ent_df = pd.DataFrame(entities, columns=["Entity_Name", "Entity_Type"])
ent_df['Entity_Name'] = ent_df['Entity_Name'].str.title()

# Remove duplicates
de_ent_df = ent_df.drop_duplicates().reset_index(drop=True)

# %%
de_ent_df["Entity_Type"].unique().tolist()

# %%
de_ent_df

# %%
df_to_csv(de2_df_para, "dying_earth2_paragraphs")
